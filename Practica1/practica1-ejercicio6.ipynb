# %%
num = input("Escribe un número: ")
numero = float(num)
if numero == 0:
    print("Cero")
elif numero < 0:
    print("Negativo")
else:
    print("Positivo")
# Out:
# Escribe un número: 8
# Positivo
